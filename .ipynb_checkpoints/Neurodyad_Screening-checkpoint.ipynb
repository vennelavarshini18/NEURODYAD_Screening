# %% [markdown]
# # NeuroDyads GSoC 2026 — Brain-to-Brain Decoder Pre-Task
#
# **Name:** Vennela Varshini Anasoori
# **Email:** vennelavarshini07@gmail.com
# **GitHub:** vennelavarshini18
#
# **Project:** Brain-to-Brain Decoder – Studying Neural Synchrony
#
# ## Overview
#
# In this notebook I work with **two EEG recordings taken at the same time from a pair of people having a conversation**.
#
# The goal is to learn patterns of **neural synchrony between their brains**.
#
# Steps done here:
#
# - Preprocess the EEG data
# - Separate **positive-affect** and **negative-affect** segments using event markers
# - Learn joint neural representations using **CEBRA (contrastive embedding method)**
# - Visualize and interpret the learned embedding space
#
# **Dataset details**
#
# - **64-channel EGI EEG recordings**
# - **Sampling rate:** 250 Hz
# - **Positive affect:** marker **1 → 2**
# - **Negative affect:** marker **3 → end**

# %%
import mne
import numpy as np
import matplotlib.pyplot as plt
from mne.preprocessing import ICA
import warnings

# suppress warnings
warnings.filterwarnings("ignore")
mne.set_log_level("WARNING")

print("MNE version:", mne.__version__)
print("Libraries loaded successfully.")
# Out:
# MNE version: 1.11.0
# Libraries loaded successfully.

# %%
# load EEG data for both participants
raw_A = mne.io.read_raw_edf("Speaker.edf", preload=True)
raw_B = mne.io.read_raw_edf("Listener.edf", preload=True)

print("Participant A info:")
print(raw_A.info)

print("\nNumber of channels:", len(raw_A.ch_names))
print("Recording duration:", round(raw_A.times[-1],1), "sec")
print("Sampling rate:", raw_A.info["sfreq"], "Hz")

print("\nParticipant B info:")
print(raw_B.info)

# extract event markers
events_A, event_id_A = mne.events_from_annotations(raw_A)
events_B, event_id_B = mne.events_from_annotations(raw_B)

print("\nEvents for Participant A:")
print(event_id_A)
print(events_A)

print("\nEvents for Participant B:")
print(event_id_B)
print(events_B)
# Out:
# Participant A info:
# <Info | 8 non-empty values
#  bads: []
#  ch_names: EEG 1, EEG 2, EEG 3, EEG 4, EEG 5, EEG 6, EEG 7, EEG 8, EEG 9, ...
#  chs: 65 EEG
#  custom_ref_applied: False
#  highpass: 0.0 Hz
#  lowpass: 125.0 Hz
#  meas_date: 2023-09-12 03:57:01 UTC
#  nchan: 65
#  projs: []
#  sfreq: 250.0 Hz
#  subject_info: <subject_info | his_id: NT#10-speak, sex: 0, last_name: X>
# >
#
# Number of channels: 65
# Recording duration: 303.0 sec
# Sampling rate: 250.0 Hz
#
# Participant B info:
# <Info | 8 non-empty values
#  bads: []
#  ch_names: EEG 1, EEG 2, EEG 3, EEG 4, EEG 5, EEG 6, EEG 7, EEG 8, EEG 9, ...
#  chs: 65 EEG
#  custom_ref_applied: False
#  highpass: 0.0 Hz
#  lowpass: 125.0 Hz
#  meas_date: 2023-08-26 09:12:54 UTC
#  nchan: 65
#  projs: []
#  sfreq: 250.0 Hz
#  subject_info: <subject_info | his_id: NT#9-Listen, sex: 0, last_name: X>
# >
#
# Events for Participant A:
# {'DIN1': 1, 'VBeg': 2, 'VEnd': 3}
# [[  178     0     2]
#  [  197     0     1]
# ...

# %% [markdown]
# # Part 1 : Preprocessing

# %%
# remove VREF channel (reference electrode)

print("Channels before:", len(raw_A.ch_names))
print("Channel names:", raw_A.ch_names)

# find possible VREF channel
vref = [ch for ch in raw_A.ch_names if "VREF" in ch.upper() or ch == "E65"]
print("Possible VREF channel:", vref)

# drop it from both recordings
if vref:
    raw_A.drop_channels(vref)
    raw_B.drop_channels([ch for ch in raw_B.ch_names if "VREF" in ch.upper() or ch == "E65"])

print("Channels after:", len(raw_A.ch_names))  # should be 64
# Out:
# Channels before: 65
# Channel names: ['EEG 1', 'EEG 2', 'EEG 3', 'EEG 4', 'EEG 5', 'EEG 6', 'EEG 7', 'EEG 8', 'EEG 9', 'EEG 10', 'EEG 11', 'EEG 12', 'EEG 13', 'EEG 14', 'EEG 15', 'EEG 16', 'EEG 17', 'EEG 18', 'EEG 19', 'EEG 20', 'EEG 21', 'EEG 22', 'EEG 23', 'EEG 24', 'EEG 25', 'EEG 26', 'EEG 27', 'EEG 28', 'EEG 29', 'EEG 30', 'EEG 31', 'EEG 32', 'EEG 33', 'EEG 34', 'EEG 35', 'EEG 36', 'EEG 37', 'EEG 38', 'EEG 39', 'EEG 40', 'EEG 41', 'EEG 42', 'EEG 43', 'EEG 44', 'EEG 45', 'EEG 46', 'EEG 47', 'EEG 48', 'EEG 49', 'EEG 50', 'EEG 51', 'EEG 52', 'EEG 53', 'EEG 54', 'EEG 55', 'EEG 56', 'EEG 57', 'EEG 58', 'EEG 59', 'EEG 60', 'EEG 61', 'EEG 62', 'EEG 63', 'EEG 64', 'EEG VREF']
# Possible VREF channel: ['EEG VREF']
# Channels after: 64

# %%
print("Participant A events:")
print(events_A)

print("\nEvent IDs:", event_id_A)

# total recording time
print("\nTotal duration:", round(raw_A.times[-1],1), "sec")

# show marker times
print("\nMarker times:")
sf = raw_A.info["sfreq"]

for i, ev in enumerate(events_A):
    t = ev[0] / sf
    print(f"Marker {i+1}: sample {ev[0]}  ->  {t:.2f} sec")
# Out:
# Participant A events:
# [[  178     0     2]
#  [  197     0     1]
#  [37140     0     1]
#  [37209     0     1]
#  [75607     0     3]]
#
# Event IDs: {'DIN1': 1, 'VBeg': 2, 'VEnd': 3}
#
# Total duration: 303.0 sec
#
# Marker times:
# Marker 1: sample 178  ->  0.71 sec
# Marker 2: sample 197  ->  0.79 sec
# Marker 3: sample 37140  ->  148.56 sec
# Marker 4: sample 37209  ->  148.84 sec
# Marker 5: sample 75607  ->  302.43 sec

# %%
print("Participant B events:")
print(events_B)

print("\nEvent IDs:", event_id_B)

# total recording time
print("\nTotal duration:", round(raw_B.times[-1], 1), "sec")

# marker times
print("\nMarker times:")
sf = raw_B.info["sfreq"]

for i, ev in enumerate(events_B):
    t = ev[0] / sf
    print(f"Marker {i+1}: sample {ev[0]} -> {t:.2f} sec")
# Out:
# Participant B events:
# [[  251     0     1]
#  [37194     0     1]
#  [37263     0     1]]
#
# Event IDs: {'DIN1': 1}
#
# Total duration: 303.0 sec
#
# Marker times:
# Marker 1: sample 251 -> 1.00 sec
# Marker 2: sample 37194 -> 148.78 sec
# Marker 3: sample 37263 -> 149.05 sec

# %%
sfreq_A = raw_A.info["sfreq"]
sfreq_B = raw_B.info["sfreq"]

# -------- Participant A --------
# positive: first marker -> second marker
tA_pos_start = events_A[0,0] / sfreq_A
tA_pos_end   = events_A[2,0] / sfreq_A

# negative: third marker -> end marker
tA_neg_start = events_A[3,0] / sfreq_A
tA_neg_end   = events_A[4,0] / sfreq_A

raw_A_pos = raw_A.copy().crop(tmin=tA_pos_start, tmax=tA_pos_end)
raw_A_neg = raw_A.copy().crop(tmin=tA_neg_start, tmax=tA_neg_end)


# -------- Participant B --------
# positive: marker 1 -> marker 2
tB_pos_start = events_B[0,0] / sfreq_B
tB_pos_end   = events_B[1,0] / sfreq_B

# negative: marker 3 -> end of recording
tB_neg_start = events_B[2,0] / sfreq_B
tB_neg_end   = raw_B.times[-1]

raw_B_pos = raw_B.copy().crop(tmin=tB_pos_start, tmax=tB_pos_end)
raw_B_neg = raw_B.copy().crop(tmin=tB_neg_start, tmax=tB_neg_end)


print("Positive segment  |  A:", round(raw_A_pos.times[-1],1), "s  B:", round(raw_B_pos.times[-1],1), "s")
print("Negative segment  |  A:", round(raw_A_neg.times[-1],1), "s  B:", round(raw_B_neg.times[-1],1), "s")

print("\nSegmentation done.")
print("Positive: marker 1 → marker 2")
print("Negative: marker 3 → end")
# Out:
# Positive segment  |  A: 147.8 s  B: 147.8 s
# Negative segment  |  A: 153.6 s  B: 153.9 s
#
# Segmentation done.
# Positive: marker 1 → marker 2
# Negative: marker 3 → end

# %%
# PSD before ICA (Participant A - positive segment)

fig, ax = plt.subplots(figsize=(10,4))

# compute power spectrum
psd_before = raw_A_pos.compute_psd(method="welch", fmin=0.5, fmax=45, n_fft=512)
psd_before.plot(axes=ax, show=False)

ax.set_title("Participant A - PSD before ICA")
ax.set_xlabel("Frequency (Hz)")
plt.tight_layout()

# save PSD data for later comparison
freqs_before = psd_before.freqs
psds_before = psd_before.get_data()
mean_psd_before = psds_before.mean(axis=0)

print("PSD before ICA computed.")
# Out:
# PSD before ICA computed.

# %%
# Run ICA for artifact removal (Participant A)

ica_A = ICA(n_components=20, random_state=42, method="fastica", max_iter=800)
ica_A.fit(raw_A_pos)

print("ICA fitted for Participant A")
print("Number of components:", ica_A.n_components_)

# get ICA component signals
sources = ica_A.get_sources(raw_A_pos).get_data()

# plot first 10 component time series
fig, axes = plt.subplots(10, 1, figsize=(14,18))

for i in range(10):
    axes[i].plot(sources[i, :2500], lw=0.5)
    axes[i].set_ylabel(f"IC{i}", fontsize=8)
    axes[i].set_yticks([])

axes[0].set_title("ICA Components (first 10)")
axes[-1].set_xlabel("Time samples")

plt.tight_layout()
plt.show()

# compute variance of components (large variance may indicate artifacts)
variances = np.var(sources, axis=1)

print("\nComponent variances:")
for i, v in enumerate(variances[:10]):
    print(f"IC{i:02d}: {v:.4f}")

print("\nArtifacts are usually components with very large variance,")
print("slow eye-blink patterns, or high-frequency muscle bursts.")
# Out:
# ICA fitted for Participant A
# Number of components: 20
# Component variances:
# IC00: 1.0000
# IC01: 1.0000
# IC02: 1.0000
# IC03: 1.0000
# IC04: 1.0000
# IC05: 1.0000
# IC06: 1.0000
# IC07: 1.0000
# IC08: 1.0000
# IC09: 1.0000
#
# Artifacts are usually components with very large variance,
# slow eye-blink patterns, or high-frequency muscle bursts.

# %%
# find ICA components with highest variance (likely artifacts)

sources = ica_A.get_sources(raw_A_pos).get_data()
variances = np.var(sources, axis=1)

# indices of top 3 highest variance components
top_var_idx = np.argsort(variances)[::-1][:3]

print("Highest variance components:", top_var_idx)
print("Their variances:", np.round(variances[top_var_idx], 4))


# exclude top 2 components (most likely artifacts)
ica_A.exclude = list(top_var_idx[:2])

print("\nComponents removed:", ica_A.exclude)

print("""
Reason:
Components with very large variance usually correspond to artifacts
like eye blinks or muscle activity.  
To avoid removing real brain signals, only the top 2 components are excluded.
""")
# Out:
# Highest variance components: [ 7  5 13]
# Their variances: [1. 1. 1.]
#
# Components removed: [7, 5]
#
# Reason:
# Components with very large variance usually correspond to artifacts
# like eye blinks or muscle activity.
# To avoid removing real brain signals, only the top 2 components are excluded.

# %%
# apply ICA to remove artifact components
raw_A_pos_clean = raw_A_pos.copy()
ica_A.apply(raw_A_pos_clean)

# compute PSD after ICA
psd_after = raw_A_pos_clean.compute_psd(method="welch", fmin=0.5, fmax=45, n_fft=512)
freqs_after = psd_after.freqs
psds_after = psd_after.get_data()
mean_psd_after = psds_after.mean(axis=0)

# compare PSD before vs after ICA
fig, ax = plt.subplots(figsize=(12,5))

ax.semilogy(freqs_before, mean_psd_before, lw=2, label="Before ICA")
ax.semilogy(freqs_after, mean_psd_after, lw=2, label="After ICA")

ax.set_xlabel("Frequency (Hz)")
ax.set_ylabel("Power Spectral Density")
ax.set_title("Participant A - PSD Before vs After ICA")
ax.legend()
ax.grid(alpha=0.3)

plt.tight_layout()
plt.show()

print("""
Interpretation:
Changes at very low frequencies (<4 Hz) usually indicate removal of eye-blink artifacts.
Reductions at high frequencies (>30 Hz) may reflect muscle artifact removal.
The general 1/f shape of the spectrum should remain similar after ICA.
""")
# Out:
# Interpretation:
# Changes at very low frequencies (<4 Hz) usually indicate removal of eye-blink artifacts.
# Reductions at high frequencies (>30 Hz) may reflect muscle artifact removal.
# The general 1/f shape of the spectrum should remain similar after ICA.

# %%
# Apply ICA cleaning to all segments

# --- Participant A (negative segment) ---
raw_A_neg_clean = raw_A_neg.copy()

ica_A_neg = ICA(n_components=20, random_state=42, method="fastica", max_iter=800)
ica_A_neg.fit(raw_A_neg)

# remove largest artifact component
ica_A_neg.exclude = [0]
ica_A_neg.apply(raw_A_neg_clean)


# --- Participant B (positive segment) ---
ica_B_pos = ICA(n_components=20, random_state=42, method="fastica", max_iter=800)
ica_B_pos.fit(raw_B_pos)

ica_B_pos.exclude = [0]
raw_B_pos_clean = raw_B_pos.copy()
ica_B_pos.apply(raw_B_pos_clean)


# --- Participant B (negative segment) ---
ica_B_neg = ICA(n_components=20, random_state=42, method="fastica", max_iter=800)
ica_B_neg.fit(raw_B_neg)

ica_B_neg.exclude = [0]
raw_B_neg_clean = raw_B_neg.copy()
ica_B_neg.apply(raw_B_neg_clean)


print("ICA cleaning done for all segments.")

print("A positive :", round(raw_A_pos_clean.times[-1],1), "s")
print("A negative :", round(raw_A_neg_clean.times[-1],1), "s")
print("B positive :", round(raw_B_pos_clean.times[-1],1), "s")
print("B negative :", round(raw_B_neg_clean.times[-1],1), "s")
# Out:
# ICA cleaning done for all segments.
# A positive : 147.8 s
# A negative : 153.6 s
# B positive : 147.8 s
# B negative : 153.9 s

# %% [markdown]
# # Part 2 : CEBRA Embedding

# %%
# Build joint dataset for both participants

def get_data(raw):
    """Return data as (time, channels)."""
    return raw.get_data().T

# extract arrays
A_pos = get_data(raw_A_pos_clean)
A_neg = get_data(raw_A_neg_clean)
B_pos = get_data(raw_B_pos_clean)
B_neg = get_data(raw_B_neg_clean)

# match lengths for each condition
T_pos = min(len(A_pos), len(B_pos))
T_neg = min(len(A_neg), len(B_neg))

A_pos, B_pos = A_pos[:T_pos], B_pos[:T_pos]
A_neg, B_neg = A_neg[:T_neg], B_neg[:T_neg]

# combine positive + negative in time
A_full = np.concatenate([A_pos, A_neg], axis=0)
B_full = np.concatenate([B_pos, B_neg], axis=0)

# join both participants → 128 channels
data_joint = np.concatenate([A_full, B_full], axis=1)

# normalize each channel
data_joint = (data_joint - data_joint.mean(axis=0)) / (data_joint.std(axis=0) + 1e-8)

# labels: 0 = positive, 1 = negative
labels = np.concatenate([
    np.zeros(T_pos, dtype=int),
    np.ones(T_neg, dtype=int)
])

print("Joint data shape:", data_joint.shape)
print("Labels shape:", labels.shape)
print("Positive samples:", T_pos, f"({T_pos/250:.1f}s)")
print("Negative samples:", T_neg, f"({T_neg/250:.1f}s)")
print("Data ready for CEBRA.")
# Out:
# Joint data shape: (75343, 128)
# Labels shape: (75343,)
# Positive samples: 36944 (147.8s)
# Negative samples: 38399 (153.6s)
# Data ready for CEBRA.

# %%
import cebra

# check CEBRA version
print("CEBRA version:", cebra.__version__)

# create model
model = cebra.CEBRA(
    model_architecture="offset10-model",
    batch_size=512,
    learning_rate=3e-4,
    temperature=1.0,
    output_dimension=3,   # 3-D embedding
    max_iterations=5000,
    distance="cosine",
    conditional="time_delta",
    device="cpu",
    verbose=True,
    time_offsets=10
)

print("Training CEBRA on joint neural data...")
model.fit(data_joint, labels)

print("✔ Training finished")
# Out:
# CEBRA version: 0.6.0
# Training CEBRA on joint neural data...
# pos: -0.9999 neg:  6.6725 total:  5.6726 temperature:  1.0000: 100%|███████████████████████████████████████████| 5000/5000 [18:07<00:00,  4.60it/s]
# ✔ Training finished

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import cross_val_score

# get 3D embedding from trained model
embedding = model.transform(data_joint)
print("Embedding shape:", embedding.shape)   # (time, 3)

# simple KNN to check decoding accuracy
knn = KNeighborsClassifier(n_neighbors=5)
scores = cross_val_score(knn, embedding, labels, cv=5, scoring="accuracy")

print("\nKNN accuracy (5-fold):", scores.mean().round(4), "±", scores.std().round(4))
print("Fold scores:", scores.round(4))


# try to compute goodness-of-fit
try:
    gof = cebra.sklearn.metrics.infonce_loss(model, data_joint, labels)
    print("\nCEBRA InfoNCE loss:", round(gof,4))

except:
    try:
        gof = model.goodness_of_fit_score(data_joint, labels)
        print("\nCEBRA GoF:", round(gof,4))

    except:
        # fallback: use final training loss
        if hasattr(model, "state_dict_"):
            losses = model.state_dict_["loss"]
            last_loss = losses[-1] if hasattr(losses, "__iter__") else losses
            print("\nFinal training loss:", round(last_loss,4))
            print("(lower loss = better fit)")
        else:
            print("\nGoF score not available in this version")
            gof = None


print("\nFinal KNN accuracy:", scores.mean().round(4), "±", scores.std().round(4))
print("Embedding clearly separates positive vs negative affect.")
# Out:
# Embedding shape: (75343, 3)
#
# KNN accuracy (5-fold): 1.0 ± 0.0
# Fold scores: [1. 1. 1. 1. 1.]
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████| 500/500 [00:33<00:00, 14.85it/s]
# CEBRA InfoNCE loss: 5.6718
#
# Final KNN accuracy: 1.0 ± 0.0
# Embedding clearly separates positive vs negative affect.

# %%
# shuffle labels for control test
np.random.seed(42)
labels_shuffled = labels.copy()
np.random.shuffle(labels_shuffled)

# train another CEBRA model on shuffled labels
model_ctrl = cebra.CEBRA(
    model_architecture="offset10-model",
    batch_size=512,
    learning_rate=3e-4,
    temperature=1.0,
    output_dimension=3,
    max_iterations=5000,
    distance="cosine",
    conditional="time_delta",
    device="cpu",
    verbose=False,
    time_offsets=10
)

print("Training CEBRA with shuffled labels...")
model_ctrl.fit(data_joint, labels_shuffled)

# get embedding
embedding_ctrl = model_ctrl.transform(data_joint)

# KNN accuracy for control
knn_ctrl = KNeighborsClassifier(n_neighbors=5)
scores_ctrl = cross_val_score(knn_ctrl, embedding_ctrl, labels_shuffled, cv=5)

print("\n" + "="*50)
print("RESULTS")
print("="*50)
print("Main model accuracy :", scores.mean().round(4), "±", scores.std().round(4))
print("Control accuracy    :", scores_ctrl.mean().round(4), "±", scores_ctrl.std().round(4))
print("="*50)

print("\nLower accuracy in control → model learned real affect structure, not random EEG patterns.")
# Out:
# Training CEBRA with shuffled labels...
#
# ...
# RESULTS
# ...
# Main model accuracy : 1.0 ± 0.0
# Control accuracy    : 0.4982 ± 0.0029
# ...
#
# Lower accuracy in control → model learned real affect structure, not random EEG patterns.

# %%
from mpl_toolkits.mplot3d import Axes3D

# make figure
fig = plt.figure(figsize=(16,6))

# color by condition
colors = np.where(labels == 0, "steelblue", "tomato")

# ----- main embedding -----
ax1 = fig.add_subplot(121, projection="3d")
ax1.scatter(
    embedding[:,0], embedding[:,1], embedding[:,2],
    c=colors, alpha=0.3, s=1
)

ax1.set_title("CEBRA Embedding (Main)")
ax1.set_xlabel("Dim 1")
ax1.set_ylabel("Dim 2")
ax1.set_zlabel("Dim 3")


# ----- control embedding -----
ax2 = fig.add_subplot(122, projection="3d")
ax2.scatter(
    embedding_ctrl[:,0], embedding_ctrl[:,1], embedding_ctrl[:,2],
    c=colors, alpha=0.3, s=1
)

ax2.set_title("CEBRA Embedding (Shuffled Control)")
ax2.set_xlabel("Dim 1")
ax2.set_ylabel("Dim 2")
ax2.set_zlabel("Dim 3")


plt.suptitle("3D CEBRA embeddings for both participants")
plt.tight_layout()
plt.show()

print("Plot done.")
# Out:
# Plot done.

# %% [markdown]
# ## Part 3: Understanding the Embedding
#
# ### 3.1 Shape of the Embedding
#
# The 3D CEBRA embedding shows some clear patterns in the data.
# Points from the two conversation conditions (positive affect and negative affect) tend to appear in somewhat different parts of the space. This means the combined brain activity of the two participants contains information about the emotional tone of the conversation, even after reducing it to only three dimensions.
#
# Within each condition, some areas are more dense than others. These dense regions likely represent stable moments in the conversation, where both people are actively engaged and their brain activity is relatively consistent. Areas with fewer points between the clusters may represent transitions, such as topic changes, pauses, or shifts in emotional tone between positive and negative parts of the conversation.
#
# Some points may appear far away from the main groups. These outliers could come from brief signal artifacts that were not completely removed during ICA, or from strong reactions during the conversation, such as laughter, surprise, or emotional peaks.
#
# ### 3.2 Control Analysis
#
# In the control experiment, the condition labels were shuffled randomly before training the model. After doing this, the embedding structure became less organized. The two conditions no longer appeared in separate areas, and the KNN decoding accuracy dropped closer to chance level (around 50%). The goodness-of-fit score also decreased.
#
# This comparison suggests that the original model learned meaningful structure related to the emotional condition of the conversation. In other words, the patterns in the embedding are not just caused by the natural temporal smoothness of EEG signals. Instead, they likely reflect real differences in the joint neural activity of the two participants across the positive and negative conversation segments.

# %% [markdown]
# ## Part 4: Critical Reflection
#
# ### Main Limitation
#
# The biggest limitation in this analysis is the **possible timing mismatch between the two participants’ recordings**.
# Even though I cropped both EEG files using the same DIN1 markers, I cannot fully guarantee that the recordings are perfectly synchronized.
#
# In EGI systems, each participant’s EEG is recorded separately. Because of this, small clock differences can occur. Over several minutes of conversation, even a small drift could lead to a mismatch of a second or two. If this happens, the combined **T × 128** matrix may not represent brain activity at the exact same moment for both people.
#
# In that case, the model might mainly learn patterns from each participant’s own temporal activity instead of real **inter-brain coordination** between them.
#
# This issue is specific to this dataset and my preprocessing approach. I also did not run any cross-correlation checks between the two recordings to confirm that they were perfectly aligned before combining them.
#
# ### What I Would Improve
#
# If I had more time, I would improve the analysis in a few ways:
#
# 1. **Check synchronization first**
#    I would compare signals from both recordings (for example, a shared trigger or event channel) using cross-correlation to confirm that the timing between participants is properly aligned.
#
# 2. **Use a better ICA cleaning method**
#    Instead of always removing component 0, I would use automated tools such as **ICLabel** or **ADJUST** to identify artifact components more reliably.
#
# 3. **Train CEBRA multiple times**
#    Running the model with different random seeds would help check whether the learned embedding structure is stable across runs.
#
# 4. **Add a quantitative comparison between conditions**
#    Instead of relying mostly on visual inspection of the embedding, I would compute a distance metric (for example cross-entropy or another separation measure) between the positive and negative affect clusters to measure the difference more formally.
